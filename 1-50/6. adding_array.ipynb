# %%
import numpy as np

# %% [markdown]
# ### Create a 3×4 array of zeros.
# Then add this 1D array [100, 200, 300, 400] to every
# row without using loop or reshape.
#
# (You should understand broadcasting rule here)

# %%
a=np.zeros((3,4))
b=np.array([100, 200, 300, 400])

# c=np.add(a,b)
c=a+b
c
# Out:
# 2
