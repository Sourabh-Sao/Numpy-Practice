# %%
import numpy as np

# %% [markdown]
# ### Create a NumPy array with values from 10 to 50 (inclusive) with step 5.
#
# ### Then print the data type (dtype) of the array.

# %%
# arange(start,stop,step)
a=np.arange(10,51,5)

#? or
# linspace(start,stop,num)
# num- this specify how many number we want
# bydefault linspace create float type array
b=np.linspace(10,50,dtype='int',num=10)

#? or
c=np.array(range(10,51,5))

#? or

d=np.ogrid[10:51:5]
# Out:
# array([10, 15, 20, 25, 30, 35, 40, 45, 50])
