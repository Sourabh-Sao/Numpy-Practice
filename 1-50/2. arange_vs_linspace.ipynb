# %%
import numpy as np

# %% [markdown]
# ### Use np.arange() to create array: [0, 2, 4, 6, 8, 10]
# ### Then use np.linspace() to create exactly same values but with 6 points (inclusive).

# %%
a=np.arange(0,12,2)

b=np.linspace(0,10,num=6,dtype='int')
b,a
# Out:
# (array([ 0,  2,  4,  6,  8, 10]), array([ 0,  2,  4,  6,  8, 10]))
